# %% [markdown]
# ![EX4-2.png](attachment:EX4-2.png)

# %% [markdown]
# Write a Python function to sum all the numbers in a list.
# Sample List : (8, 2, 3, 0, 7)
# Expected Output : 20

# %%
#--------------Q1
def sum_list(x)

# %%
n=int(input('entr a num'))
for i in range(1,11):
    a=i*n
    print(i,'x', n ,'=', a)
# Out:
# entr a num555
# 1 x 555 = 555
# 2 x 555 = 1110
# 3 x 555 = 1665
# 4 x 555 = 2220
# 5 x 555 = 2775
# 6 x 555 = 3330
# 7 x 555 = 3885
# 8 x 555 = 4440
# 9 x 555 = 4995
# 10 x 555 = 5550
